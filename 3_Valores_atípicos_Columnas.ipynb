# %% [markdown]
# <a href="https://colab.research.google.com/github/andilugo/Valores-Atipicos/blob/main/3_Valores_at%C3%ADpicos_Columnas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Valores atípicos Columnas**
# Andrea Cosset Hernández Lugo A01707744

# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Cargar archivo csv desde equipo
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-e30ebd94-e271-4a91-bc47-fa2b34ee7694" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e30ebd94-e271-4a91-bc47-fa2b34ee7694">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Carga desde un archivo csv sin indice
data= pd.read_csv('ventastotales_sin_nulos.csv')
data
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %%
#Obtengo información del Dataframe
data.head()
# Out:
#    Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0           0    01/01/2017                    27858.9
# 1           1    01/02/2017                    25994.2
# 2           2    01/03/2017                    27780.0
# 3           3    01/04/2017                    29134.3
# 4           4    01/05/2017                    27969.0
#
#    ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                    27477.3                 27858872.08   27591730.13
# 1                    25223.4                 25994200.17   25749179.40
# 2                    26334.3                 27780006.52   27472228.72
# 3                    27045.9                 29134272.22   28827479.49
# 4                    25631.9                 27969004.68   27569311.41
#
#    canales_on_line  ventas_totales_medio_pago      efectivo  tarjetas_debito  \
# 0       267141.956                27858872.08  1.023010e+07      6864575.384
# ...

# %%
#Corroboramos valores nulos
valores_nulos=data.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0                             0
# indice_tiempo                          0
# ventas_precios_corrientes              0
# ventas_precios_constantes              0
# ventas_totales_canal_venta             0
# salon_ventas                           0
# canales_on_line                        0
# ventas_totales_medio_pago              0
# efectivo                               0
# tarjetas_debito                        0
# tarjetas_credito                       0
# otros_medios                           0
# ventas_totales_grupo_articulos         0
# subtotal_ventas_alimentos_bebidas      0
# bebidas                                0
# almacen                                0
# panaderia                              0
# lacteos                                0
# carnes                                 0
# verduleria_fruteria                    0
# alimentos_preparados_rotiseria         0
# articulos_limpieza_perfumeria          0
# indumentaria_calzado_textiles_hogar    0
# ...

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(10, 6))
plt.boxplot(data["otros"]) 
plt.title("Outliers de Precio Venta")
plt.show() #dibujamos el diagrama

# %% [markdown]
# # **MÉTODO DE IQR (RANGO INTER QUARTILICO)**

# %% [markdown]
# # Variable 1

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(10, 6))
plt.boxplot(data["ventas_precios_corrientes"]) 
plt.title("Outliers de ventas_precios_corrientes")
plt.show() #dibujamos el diagrama

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=data["ventas_precios_corrientes"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 192319.35000000003
# Limite inferior permitido -59178.650000000016

# %%
#Encontramos Ouliers
outliers_iqr= data[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 42          42    01/07/2020                   211140.7
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 42                    50791.4                 81140696.22   76413721.76
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 42      4726974.457                81140696.22  24935747.29      22143208.63
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 42  ...  23393038.41  2630487.791  9592798.115  8463266.123
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 42          2712593.828                     518942.5376
#
#     articulos_limpieza_perfumeria  indumentaria_calzado_textiles_hogar  \
# 42                    11217153.19                          2502616.619
#
#     electronicos_articulos_hogar        otros
# 42                   6125265.839  5935993.913
#
# [1 rows x 25 columns]

# %%
#Obtenemos datos limpios
data_clean_iqr1= data[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data_clean_iqr1
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean_iqr1["ventas_precios_corrientes"]) 
plt.title("Outliers de ventas_precios_corrientes")
data_clean_iqr1.to_csv("Variable ventas_precios_corrientes")
data_clean_iqr1
plt.show() #dibujamos el diagrama

# %% [markdown]
# # Variable 2

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(10, 6))
plt.boxplot(data["ventas_precios_constantes"]) 
plt.title("Outliers de ventas_precios_constantes")
plt.show() #dibujamos el diagrama

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=data["ventas_precios_constantes"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 31938.75
# Limite inferior permitido 18759.949999999997

# %%
#Encontramos Ouliers
outliers_iqr= data[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 11          11    01/12/2017                    40766.3
# 42          42    01/07/2020                   211140.7
# 60          60    01/01/2022                   154517.1
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 11                    34084.5                4.076632e+07  4.032029e+07
# 42                    50791.4                8.114070e+07  7.641372e+07
# 60                    45463.4                1.545171e+08  1.496976e+08
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 11     4.460368e+05               4.076632e+07  13710305.37      11070098.74
# 42     4.726974e+06               8.114070e+07  24935747.29      22143208.63
# 60     4.819480e+06               1.545171e+08  46962602.22      46053650.13
#
#     ...       almacen    panaderia       lacteos        carnes  \
# 11  ...  9.667850e+06  1346130.813  3.684165e+06  3.674954e+06
# ...

# %%
#Obtenemos datos limpios
data_clean_iqr2= data[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data_clean_iqr2
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 59          59    01/12/2021                   183983.2
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean_iqr2["ventas_precios_constantes"]) 
plt.title("Outliers de ventas_precios_constantes")
data_clean_iqr2.to_csv("Variable ventas_precios_constantes")
data_clean_iqr2
plt.show() #dibujamos el diagrama

# %% [markdown]
# # Variable 3

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(10, 6))
plt.boxplot(data["salon_ventas"]) 
plt.title("Outliers de salon_ventas")
plt.show() #dibujamos el diagrama

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=data["salon_ventas"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 170440082.58499998
# Limite inferior permitido -32001350.254999995

# %%
#Encontramos Ouliers
outliers_iqr= data[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 59          59    01/12/2021                   183983.2
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 59                    31595.7                 183983151.9   178866721.2
# 63                    24140.5                 177148082.8   173003799.1
# 64                    23234.2                 179639238.6   175358487.5
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 59      5116430.634                183983151.9  56640033.15      55432191.37
# 63      4144283.743                177148082.8  53189998.68      50063972.79
# 64      4280751.113                179639238.6  52738110.62      49886787.86
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 59  ...  45199914.72  5859939.041  16275221.46  21265049.45
# ...

# %%
#Obtenemos datos limpios
data_clean_iqr3= data[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data_clean_iqr3
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 57          57    01/10/2021                   140487.5
# 58          58    01/11/2021                   141702.0
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean_iqr3["salon_ventas"]) 
plt.title("Outliers de salon_ventas")
data_clean_iqr3.to_csv("Variable salon_ventas")
data_clean_iqr3
plt.show() #dibujamos el diagrama

# %% [markdown]
# # Variable 4

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(10, 6))
plt.boxplot(data["tarjetas_debito"]) 
plt.title("Outliers de tarjetas_debito")
plt.show() #dibujamos el diagrama

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=data["tarjetas_debito"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 50952216.5835
# Limite inferior permitido -15349161.052499998

# %%
#Encontramos Ouliers
outliers_iqr= data[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 59          59    01/12/2021                   183983.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 59                    31595.7                 183983151.9   178866721.2
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 59      5116430.634                183983151.9  56640033.15      55432191.37
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 59  ...  45199914.72  5859939.041  16275221.46  21265049.45
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 59          5863700.608                     1679028.685
#
#     articulos_limpieza_perfumeria  indumentaria_calzado_textiles_hogar  \
# 59                    21753939.73                          4759532.634
#
#     electronicos_articulos_hogar        otros
# 59                   12669269.76  16665123.15
#
# [1 rows x 25 columns]

# %%
#Obtenemos datos limpios
data_clean_iqr4= data[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data_clean_iqr4
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean_iqr4["tarjetas_debito"]) 
plt.title("Outliers de tarjetas_debito")
data_clean_iqr4.to_csv("Variable tarjetas_debito")
data_clean_iqr4
plt.show() #dibujamos el diagrama

# %% [markdown]
# # Variable 5

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(10, 6))
plt.boxplot(data["tarjetas_credito"]) 
plt.title("Outliers de tarjetas_credito")
plt.show() #dibujamos el diagrama

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=data["tarjetas_credito"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 63856184.05500001
# Limite inferior permitido -16515482.225

# %%
#Encontramos Ouliers
outliers_iqr= data[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 63                    24140.5                 177148082.8   173003799.1
# 64                    23234.2                 179639238.6   175358487.5
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 63      4144283.743                177148082.8  53189998.68      50063972.79
# 64      4280751.113                179639238.6  52738110.62      49886787.86
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 63  ...  49991675.91  6746166.557  19309461.59  22877841.24
# 64  ...  50150351.46  6667329.665  20121124.43  22841532.85
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 63          6510665.781                     1719458.547
# ...

# %%
#Obtenemos datos limpios
data_clean_iqr5= data[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data_clean_iqr5
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 58          58    01/11/2021                   141702.0
# 59          59    01/12/2021                   183983.2
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean_iqr5["tarjetas_credito"]) 
plt.title("Outliers de tarjetas_credito")
data_clean_iqr5.to_csv("Variable tarjetas_credito")
data_clean_iqr5
plt.show() #dibujamos el diagrama

# %% [markdown]
# # Variable 6

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(10, 6))
plt.boxplot(data["subtotal_ventas_alimentos_bebidas"]) 
plt.title("Outliers de subtotal_ventas_alimentos_bebidas")
plt.show() #dibujamos el diagrama

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=data["subtotal_ventas_alimentos_bebidas"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 114548006.925
# Limite inferior permitido -11790048.954999998

# %%
#Encontramos Ouliers
outliers_iqr= data[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 59          59    01/12/2021                   183983.2
# 62          62    01/03/2022                       16.5
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 59                    31595.7                 183983151.9   178866721.2
# 62                    24612.4                 168982502.3   164321107.3
# 63                    24140.5                 177148082.8   173003799.1
# 64                    23234.2                 179639238.6   175358487.5
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 59     5.116431e+06                183983151.9  56640033.15      55432191.37
# 62     4.661350e+05                168982502.3  51262080.99      47364363.88
# 63     4.144284e+06                177148082.8  53189998.68      50063972.79
# ...

# %%
#Obtenemos datos limpios
data_clean_iqr6= data[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data_clean_iqr6
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 56          56    01/09/2021                   123002.3
# 57          57    01/10/2021                   140487.5
# 58          58    01/11/2021                   141702.0
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean_iqr6["subtotal_ventas_alimentos_bebidas"]) 
plt.title("Outliers de subtotal_ventas_alimentos_bebidas")
data_clean_iqr6.to_csv("Variable subtotal_ventas_alimentos_bebidas")
data_clean_iqr6
plt.show() #dibujamos el diagrama

# %% [markdown]
# # **Método de desviación estándar**

# %% [markdown]
# # Variable 7

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(10, 6))
plt.boxplot(data["bebidas"]) 
plt.title("Outliers de bebidas")
plt.show() #dibujamos el diagrama

# %%
#Método aplicando desviación estandar. Encuentro los valores extremos
y=data["bebidas"]
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido 26655132.189003326
# Limite inferior permitido -9170860.941372558

# %%
#Encontramos Ouliers
outliers= data[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 59          59    01/12/2021                   183983.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 59                    31595.7                 183983151.9   178866721.2
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 59      5116430.634                183983151.9  56640033.15      55432191.37
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 59  ...  45199914.72  5859939.041  16275221.46  21265049.45
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 59          5863700.608                     1679028.685
#
#     articulos_limpieza_perfumeria  indumentaria_calzado_textiles_hogar  \
# 59                    21753939.73                          4759532.634
#
#     electronicos_articulos_hogar        otros
# 59                   12669269.76  16665123.15
#
# [1 rows x 25 columns]

# %%
#Obtenemos datos limpios
data_clean7= data[(y<=Limite_Superior)&(y>=Limite_Inferior)]
data_clean7
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean7["bebidas"]) 
plt.title("Outliers de bebidas")
data_clean7.to_csv("Variable bebidas")
data_clean7
plt.show() #dibujamos el diagrama

# %% [markdown]
# # Variable 8

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(10, 6))
plt.boxplot(data["panaderia"]) 
plt.title("Outliers de panaderia")
plt.show() #dibujamos el diagrama

# %%
#Método aplicando desviación estandar. Encuentro los valores extremos
y=data["panaderia"]
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)

# %%
#Encontramos Ouliers
outliers= data[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, indice_tiempo, ventas_precios_corrientes, ventas_precios_constantes, ventas_totales_canal_venta, salon_ventas, canales_on_line, ventas_totales_medio_pago, efectivo, tarjetas_debito, tarjetas_credito, otros_medios, ventas_totales_grupo_articulos, subtotal_ventas_alimentos_bebidas, bebidas, almacen, panaderia, lacteos, carnes, verduleria_fruteria, alimentos_preparados_rotiseria, articulos_limpieza_perfumeria, indumentaria_calzado_textiles_hogar, electronicos_articulos_hogar, otros]
# Index: []
#
# [0 rows x 25 columns]

# %%
#Obtenemos datos limpios
data_clean8= data[(y<=Limite_Superior)&(y>=Limite_Inferior)]
data_clean8
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean8["panaderia"]) 
plt.title("Outliers de panaderia")
data_clean8.to_csv("Variable panaderia")
data_clean8
plt.show() #dibujamos el diagrama

# %% [markdown]
# # Variable 9

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(10, 6))
plt.boxplot(data["alimentos_preparados_rotiseria"]) 
plt.title("Outliers de alimentos_preparados_rotiseria")
plt.show() #dibujamos el diagrama

# %%
#Método aplicando desviación estandar. Encuentro los valores extremos
y=data["alimentos_preparados_rotiseria"]
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido 1816247.6169503073
# Limite inferior permitido -458293.08703030716

# %%
#Encontramos Ouliers
outliers= data[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, indice_tiempo, ventas_precios_corrientes, ventas_precios_constantes, ventas_totales_canal_venta, salon_ventas, canales_on_line, ventas_totales_medio_pago, efectivo, tarjetas_debito, tarjetas_credito, otros_medios, ventas_totales_grupo_articulos, subtotal_ventas_alimentos_bebidas, bebidas, almacen, panaderia, lacteos, carnes, verduleria_fruteria, alimentos_preparados_rotiseria, articulos_limpieza_perfumeria, indumentaria_calzado_textiles_hogar, electronicos_articulos_hogar, otros]
# Index: []
#
# [0 rows x 25 columns]

# %%
#Obtenemos datos limpios
data_clean9= data[(y<=Limite_Superior)&(y>=Limite_Inferior)]
data_clean9
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean9["alimentos_preparados_rotiseria"]) 
plt.title("Outliers de alimentos_preparados_rotiseria")
data_clean9.to_csv("Variable alimentos_preparados_rotiseria")
data_clean9
plt.show() #dibujamos el diagrama

# %% [markdown]
# # Variable 10

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(10, 6))
plt.boxplot(data["indumentaria_calzado_textiles_hogar"]) 
plt.title("Outliers de indumentaria_calzado_textiles_hogar")
plt.show() #dibujamos el diagrama

# %%
#Método aplicando desviación estandar. Encuentro los valores extremos
y=data["indumentaria_calzado_textiles_hogar"]
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido 5156970.953168336
# Limite inferior permitido -1604600.4128114134

# %%
#Encontramos Ouliers
outliers= data[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 64                    23234.2                 179639238.6   175358487.5
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 64      4280751.113                179639238.6  52738110.62      49886787.86
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 64  ...  50150351.46  6667329.665  20121124.43  22841532.85
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 64           6314109.47                     1779482.857
#
#     articulos_limpieza_perfumeria  indumentaria_calzado_textiles_hogar  \
# 64                    23578638.71                          5213152.564
#
#     electronicos_articulos_hogar        otros
# 64                   12039595.55  12349980.06
#
# [1 rows x 25 columns]

# %%
#Obtenemos datos limpios
data_clean10= data[(y<=Limite_Superior)&(y>=Limite_Inferior)]
data_clean10
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 59          59    01/12/2021                   183983.2
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
# 63          63    01/04/2022                   177148.1
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean10["indumentaria_calzado_textiles_hogar"]) 
plt.title("Outliers de indumentaria_calzado_textiles_hogar")
data_clean10.to_csv("Variable indumentaria_calzado_textiles_hogar")
data_clean10
plt.show() #dibujamos el diagrama

# %% [markdown]
# # Variable 11

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(10, 6))
plt.boxplot(data["electronicos_articulos_hogar"]) 
plt.title("Outliers de electronicos_articulos_hogar")
plt.show() #dibujamos el diagrama

# %%
#Método aplicando desviación estandar. Encuentro los valores extremos
y=data["electronicos_articulos_hogar"]
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido 14473003.904107107
# Limite inferior permitido -5606376.954814801

# %%
#Encontramos Ouliers
outliers= data[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, indice_tiempo, ventas_precios_corrientes, ventas_precios_constantes, ventas_totales_canal_venta, salon_ventas, canales_on_line, ventas_totales_medio_pago, efectivo, tarjetas_debito, tarjetas_credito, otros_medios, ventas_totales_grupo_articulos, subtotal_ventas_alimentos_bebidas, bebidas, almacen, panaderia, lacteos, carnes, verduleria_fruteria, alimentos_preparados_rotiseria, articulos_limpieza_perfumeria, indumentaria_calzado_textiles_hogar, electronicos_articulos_hogar, otros]
# Index: []
#
# [0 rows x 25 columns]

# %%
#Obtenemos datos limpios
data_clean11= data[(y<=Limite_Superior)&(y>=Limite_Inferior)]
data_clean11
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean11["electronicos_articulos_hogar"]) 
plt.title("Outliers de electronicos_articulos_hogar")
data_clean11.to_csv("Variable electronicos_articulos_hogar")
data_clean11
plt.show() #dibujamos el diagrama

# %% [markdown]
# # Variable 12

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(10, 6))
plt.boxplot(data["otros"]) 
plt.title("Outliers de otros")
plt.show() #dibujamos el diagrama

# %%
#Método aplicando desviación estandar. Encuentro los valores extremos
y=data["otros"]
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido 15951727.352466527
# Limite inferior permitido -5110613.031420373

# %%
#Encontramos Ouliers
outliers= data[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 59          59    01/12/2021                   183983.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 59                    31595.7                 183983151.9   178866721.2
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 59      5116430.634                183983151.9  56640033.15      55432191.37
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 59  ...  45199914.72  5859939.041  16275221.46  21265049.45
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 59          5863700.608                     1679028.685
#
#     articulos_limpieza_perfumeria  indumentaria_calzado_textiles_hogar  \
# 59                    21753939.73                          4759532.634
#
#     electronicos_articulos_hogar        otros
# 59                   12669269.76  16665123.15
#
# [1 rows x 25 columns]

# %%
#Obtenemos datos limpios
data_clean12= data[(y<=Limite_Superior)&(y>=Limite_Inferior)]
data_clean12
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean12["otros"]) 
plt.title("Outliers de otros")
data_clean12.to_csv("Variable otros")
data_clean12
plt.show() #dibujamos el diagrama
