# %% [markdown]
# <a href="https://colab.research.google.com/github/andilugo/Valores-Atipicos/blob/main/2020_Valores_at%C3%ADpicos_DataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Cargar archivo csv desde equipo
from google.colab import files
files.upload()

# %% [markdown]
# # 2020

# %%
#Carga desde un archivo .csv sin indice
data= pd.read_excel('Gastos y costos 20-23.xlsx',sheet_name="2020")

# %%
#Verificamos información del DataFrame
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3342 entries, 0 to 3341
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   FECHA        3342 non-null   datetime64[ns]
#  1   FOLIO        3153 non-null   object
#  2   UUID         3342 non-null   object
#  3   RFC          3342 non-null   object
#  4   PROVEEDOR    3342 non-null   object
#  5   TIPO GASTO   3342 non-null   object
#  6   GASTO        840 non-null    object
#  7   DESCRIPCION  3342 non-null   object
#  8   TC           2951 non-null   float64
#  9   IMPORTE      3308 non-null   float64
#  10  IVA          3074 non-null   float64
#  11  RET ISR      3342 non-null   float64
#  12  RET IVA      3342 non-null   float64
#  13  TOTAL MX     3342 non-null   float64
#  14  TOTAL SAT    3342 non-null   float64
#  15  TIPO         3341 non-null   object
#  16  STATUS       3342 non-null   object
#  17  POLIZA       21 non-null     object
# ...

# %%
#Corroboramos valores nulos
valores_nulos=data.isnull().sum()
valores_nulos
# Out:
# FECHA             0
# FOLIO           189
# UUID              0
# RFC               0
# PROVEEDOR         0
# TIPO GASTO        0
# GASTO          2502
# DESCRIPCION       0
# TC              391
# IMPORTE          34
# IVA             268
# RET ISR           0
# RET IVA           0
# TOTAL MX          0
# TOTAL SAT         0
# TIPO              1
# STATUS            0
# POLIZA         3321
# Columna1          0
# dtype: int64

# %% [markdown]
# ## **PROCEDIMIENTO PARA ELIMINAR VALORES NULOS EN DATAFRAME**

# %%
#Reemplazamos valores nulos del dataframe con "bfill"
data1 =data.fillna(method="bfill") 
data1
# Out:
#           FECHA                   FOLIO                                  UUID  \
# 0    2020-01-01                   39408  BD20F436-72CC-4BE2-AD37-5999D71AA391
# 1    2020-01-01  0001010100750847116902  85AEAC2E-6395-44A0-9CB9-754D06893375
# 2    2020-01-01  0001010100752163714102  BD0DFE85-D776-41CB-9C5C-4FA7923E687A
# 3    2020-01-01                    3663  EF4504D6-830D-415C-AF03-80CF54C5E28E
# 4    2020-01-01                    2849  EC2F4AA4-BA64-4E2E-A5B7-4EBBE042D6D3
# ...         ...                     ...                                   ...
# 3337 2020-12-01                  125834  80BCB1D8-673F-495B-9C2A-4AC9F9CB38E5
# 3338 2020-12-01                   37652  D4C7C1FB-03A7-4046-A2BD-03EBE7DA861E
# 3339 2020-12-01                     160  FFCEE7D4-1F38-4D44-BE02-EB042DAACEE7
# 3340 2020-12-01                  634875  8DFF4F01-2F8B-4085-B116-05A314108B02
# 3341 2020-12-01                 1044477  F18225D6-4024-4F03-A15A-D18917386D59
#
# ...

# %%
#Corroboramos valores nulos del dataframe
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# FECHA             0
# FOLIO             0
# UUID              0
# RFC               0
# PROVEEDOR         0
# TIPO GASTO        0
# GASTO             0
# DESCRIPCION       0
# TC                0
# IMPORTE           0
# IVA               0
# RET ISR           0
# RET IVA           0
# TOTAL MX          0
# TOTAL SAT         0
# TIPO              0
# STATUS            0
# POLIZA         2898
# Columna1          0
# dtype: int64

# %%
#Reemplazamos valores nulos del dataframe con "mean"
#Realizamos una copia del dataframe
data2=data.copy()
data2=data2.fillna(round(data.mean(),1))
data2
# Out:
# <ipython-input-24-1c13554a70f8>:4: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   data2=data2.fillna(round(data.mean(),1))
# <ipython-input-24-1c13554a70f8>:4: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data2=data2.fillna(round(data.mean(),1))
#           FECHA                   FOLIO                                  UUID  \
# 0    2020-01-01                   39408  BD20F436-72CC-4BE2-AD37-5999D71AA391
# 1    2020-01-01  0001010100750847116902  85AEAC2E-6395-44A0-9CB9-754D06893375
# 2    2020-01-01  0001010100752163714102  BD0DFE85-D776-41CB-9C5C-4FA7923E687A
# 3    2020-01-01                    3663  EF4504D6-830D-415C-AF03-80CF54C5E28E
# ...

# %%
#Corroboramos valores nulos del dataframe
valores_nulos=data2.isnull().sum()
valores_nulos
# Out:
# FECHA             0
# FOLIO           189
# UUID              0
# RFC               0
# PROVEEDOR         0
# TIPO GASTO        0
# GASTO          2502
# DESCRIPCION       0
# TC                0
# IMPORTE           0
# IVA               0
# RET ISR           0
# RET IVA           0
# TOTAL MX          0
# TOTAL SAT         0
# TIPO              1
# STATUS            0
# POLIZA         3321
# Columna1          0
# dtype: int64

# %%
#Realizamos diagrama de caja o bigote de cada columna del dataframe
fig = plt.figure(figsize =(15, 8))
data2.plot(kind='box', vert=False)
plt.title("Valores Atípicos del Dataframe")
plt.show() #dibujamos el diagrama

# %% [markdown]
# ##**PROCEDIMIENTO "DESVIACIÓN ESTÁNDAR" PARA ELIMINAR OUTLIERS EN DATAFRAME**

# %%
cuanti2020=data2.drop(['RFC','FECHA','FOLIO','UUID', 'PROVEEDOR','TIPO GASTO','TIPO', 'DESCRIPCION', 'STATUS', 'POLIZA'], axis=1)
cuanti2020
# Out:
#        TC   IMPORTE      IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT  Columna1
# 0     1.0      0.00  2248.28      0.0      0.0   2248.28   16300.00  14051.72
# 1     1.0    490.00    78.40      0.0      0.0    568.40     568.40      0.00
# 2     1.0    195.00    31.20      0.0      0.0    226.20     226.20      0.00
# 3     1.0  10694.25  1711.08      0.0      0.0  12405.33   12405.33      0.00
# 4     1.0      0.00   519.80      0.0      0.0      0.00       0.00      0.00
# ...   ...       ...      ...      ...      ...       ...        ...       ...
# 3337  1.0    129.79    20.21      0.0      0.0    150.00     150.00      0.00
# 3338  1.0   2284.80   365.57      0.0      0.0   2650.37    2650.37      0.00
# 3339  1.0    163.79    26.21      0.0      0.0    190.00     190.00      0.00
# 3340  1.0      0.00     0.00      0.0      0.0      0.00       0.00      0.00
# 3341  1.0  14889.29     0.00      0.0      0.0  14889.29   14889.29      0.00
#
# [3342 rows x 8 columns]

# %%
cuali2020=data2.drop([ 'TC',	'IMPORTE','GASTO',	'IVA', 'RET ISR',	'RET IVA', 'TOTAL MX',	'TOTAL SAT',	'Columna1' ], axis=1)
cuali2020
# Out:
#           FECHA                   FOLIO                                  UUID  \
# 0    2020-01-01                   39408  BD20F436-72CC-4BE2-AD37-5999D71AA391
# 1    2020-01-01  0001010100750847116902  85AEAC2E-6395-44A0-9CB9-754D06893375
# 2    2020-01-01  0001010100752163714102  BD0DFE85-D776-41CB-9C5C-4FA7923E687A
# 3    2020-01-01                    3663  EF4504D6-830D-415C-AF03-80CF54C5E28E
# 4    2020-01-01                    2849  EC2F4AA4-BA64-4E2E-A5B7-4EBBE042D6D3
# ...         ...                     ...                                   ...
# 3337 2020-12-01                  125834  80BCB1D8-673F-495B-9C2A-4AC9F9CB38E5
# 3338 2020-12-01                   37652  D4C7C1FB-03A7-4046-A2BD-03EBE7DA861E
# 3339 2020-12-01                     160  FFCEE7D4-1F38-4D44-BE02-EB042DAACEE7
# 3340 2020-12-01                  634875  8DFF4F01-2F8B-4085-B116-05A314108B02
# 3341 2020-12-01                 1044477  F18225D6-4024-4F03-A15A-D18917386D59
#
# ...

# %%
#Método aplicando desviación estandar. Encuentro los valores extremos
y=cuanti2020
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido TC               4.251032
# IMPORTE      25167.992859
# IVA           4563.165637
# RET ISR        667.271992
# RET IVA        958.239955
# TOTAL MX     28488.002843
# TOTAL SAT    33250.398514
# Columna1     14626.999268
# dtype: float64
# Limite inferior permitido TC              -2.117814
# IMPORTE     -18869.298785
# IVA          -3523.520012
# RET ISR       -627.750813
# RET IVA       -839.215179
# TOTAL MX    -21455.655297
# TOTAL SAT   -25762.462834
# Columna1    -14171.411134
# dtype: float64

# %%
#Encontramos Ouliers del Dataframe
outliers= cuanti2020[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers
# Out:
#       TC  IMPORTE  IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT  Columna1
# 0    NaN      NaN  NaN      NaN      NaN       NaN        NaN       NaN
# 1    NaN      NaN  NaN      NaN      NaN       NaN        NaN       NaN
# 2    NaN      NaN  NaN      NaN      NaN       NaN        NaN       NaN
# 3    NaN      NaN  NaN      NaN      NaN       NaN        NaN       NaN
# 4    NaN      NaN  NaN      NaN      NaN       NaN        NaN       NaN
# ...   ..      ...  ...      ...      ...       ...        ...       ...
# 3337 NaN      NaN  NaN      NaN      NaN       NaN        NaN       NaN
# 3338 NaN      NaN  NaN      NaN      NaN       NaN        NaN       NaN
# 3339 NaN      NaN  NaN      NaN      NaN       NaN        NaN       NaN
# 3340 NaN      NaN  NaN      NaN      NaN       NaN        NaN       NaN
# 3341 NaN      NaN  NaN      NaN      NaN       NaN        NaN       NaN
#
# [3342 rows x 8 columns]

# %%
#Obtenemos datos y los outliers se convierten en nulos en el DataFrame
data3= cuanti2020[(y<=Limite_Superior)&(y>=Limite_Inferior)]
data3
# Out:
#        TC   IMPORTE      IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT  Columna1
# 0     1.0      0.00  2248.28      0.0      0.0   2248.28   16300.00  14051.72
# 1     1.0    490.00    78.40      0.0      0.0    568.40     568.40      0.00
# 2     1.0    195.00    31.20      0.0      0.0    226.20     226.20      0.00
# 3     1.0  10694.25  1711.08      0.0      0.0  12405.33   12405.33      0.00
# 4     1.0      0.00   519.80      0.0      0.0      0.00       0.00      0.00
# ...   ...       ...      ...      ...      ...       ...        ...       ...
# 3337  1.0    129.79    20.21      0.0      0.0    150.00     150.00      0.00
# 3338  1.0   2284.80   365.57      0.0      0.0   2650.37    2650.37      0.00
# 3339  1.0    163.79    26.21      0.0      0.0    190.00     190.00      0.00
# 3340  1.0      0.00     0.00      0.0      0.0      0.00       0.00      0.00
# 3341  1.0  14889.29     0.00      0.0      0.0  14889.29   14889.29      0.00
#
# [3342 rows x 8 columns]

# %%
#Corroboramos valores nulos del dataframe4
valores_nulos=cuanti2020.isnull().sum()
valores_nulos
# Out:
# TC           0
# IMPORTE      0
# IVA          0
# RET ISR      0
# RET IVA      0
# TOTAL MX     0
# TOTAL SAT    0
# Columna1     0
# dtype: int64

# %%
#Reemplazamos valores atípicos (nulos) del dataframe con "mean"
#Realizamos una copia del dataframe
data_clean=cuali2020.copy()
data_clean=data_clean.fillna(round(cuali2020.mean(),1))
data_clean
# Out:
# <ipython-input-78-45be5e7c9454>:4: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   data_clean=data_clean.fillna(round(cuali2020.mean(),1))
# <ipython-input-78-45be5e7c9454>:4: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data_clean=data_clean.fillna(round(cuali2020.mean(),1))
#           FECHA                   FOLIO                                  UUID  \
# 0    2020-01-01                   39408  BD20F436-72CC-4BE2-AD37-5999D71AA391
# 1    2020-01-01  0001010100750847116902  85AEAC2E-6395-44A0-9CB9-754D06893375
# 2    2020-01-01  0001010100752163714102  BD0DFE85-D776-41CB-9C5C-4FA7923E687A
# ...

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=data_clean.isnull().sum()
valores_nulos
# Out:
# FECHA             0
# FOLIO           189
# UUID              0
# RFC               0
# PROVEEDOR         0
# TIPO GASTO        0
# DESCRIPCION       0
# TIPO              1
# STATUS            0
# POLIZA         3321
# dtype: int64

# %%
# Unimos laos datas con el dataframe
Datos_limpios2020_desv = pd.concat([cuanti2020, cuali2020], axis=1)
Datos_limpios2020_desv
# Out:
#        TC   IMPORTE      IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT  Columna1  \
# 0     1.0      0.00  2248.28      0.0      0.0   2248.28   16300.00  14051.72
# 1     1.0    490.00    78.40      0.0      0.0    568.40     568.40      0.00
# 2     1.0    195.00    31.20      0.0      0.0    226.20     226.20      0.00
# 3     1.0  10694.25  1711.08      0.0      0.0  12405.33   12405.33      0.00
# 4     1.0      0.00   519.80      0.0      0.0      0.00       0.00      0.00
# ...   ...       ...      ...      ...      ...       ...        ...       ...
# 3337  1.0    129.79    20.21      0.0      0.0    150.00     150.00      0.00
# 3338  1.0   2284.80   365.57      0.0      0.0   2650.37    2650.37      0.00
# 3339  1.0    163.79    26.21      0.0      0.0    190.00     190.00      0.00
# 3340  1.0      0.00     0.00      0.0      0.0      0.00       0.00      0.00
# 3341  1.0  14889.29     0.00      0.0      0.0  14889.29   14889.29      0.00
#
# ...

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=Datos_limpios2020_desv.isnull().sum()
valores_nulos
# Out:
# TC                0
# IMPORTE           0
# IVA               0
# RET ISR           0
# RET IVA           0
# TOTAL MX          0
# TOTAL SAT         0
# Columna1          0
# FECHA             0
# FOLIO           189
# UUID              0
# RFC               0
# PROVEEDOR         0
# TIPO GASTO        0
# DESCRIPCION       0
# TIPO              1
# STATUS            0
# POLIZA         3321
# dtype: int64

# %%
#Convertir DataFrame a CSV
Datos_limpios2020_desv.to_csv("Datos_limpios2020_desv.csv")

# %% [markdown]
# ##**PROCEDIMIENTO "CUANTILES" PARA SUSTITUIR OUTLIERS EN DATAFRAME**

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=cuanti2020

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido TC              1.00000
# IMPORTE      7492.26375
# IVA          1280.63375
# RET ISR         0.00000
# RET IVA         0.00000
# TOTAL MX     7983.17750
# TOTAL SAT    8269.28375
# Columna1        0.00000
# dtype: float64
# Limite inferior permitido TC              1.00000
# IMPORTE     -4465.00625
# IVA          -748.25625
# RET ISR         0.00000
# RET IVA         0.00000
# TOTAL MX    -4783.14250
# TOTAL SAT   -4832.96625
# Columna1        0.00000
# dtype: float64

# %%
#Encontramos Outliers del Dataframe
outliers_iqr= cuanti2020[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#       TC   IMPORTE      IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT  Columna1
# 0    NaN       NaN  2248.28      NaN      NaN       NaN   16300.00  14051.72
# 1    NaN       NaN      NaN      NaN      NaN       NaN        NaN       NaN
# 2    NaN       NaN      NaN      NaN      NaN       NaN        NaN       NaN
# 3    NaN  10694.25  1711.08      NaN      NaN  12405.33   12405.33       NaN
# 4    NaN       NaN      NaN      NaN      NaN       NaN        NaN       NaN
# ...   ..       ...      ...      ...      ...       ...        ...       ...
# 3337 NaN       NaN      NaN      NaN      NaN       NaN        NaN       NaN
# 3338 NaN       NaN      NaN      NaN      NaN       NaN        NaN       NaN
# 3339 NaN       NaN      NaN      NaN      NaN       NaN        NaN       NaN
# 3340 NaN       NaN      NaN      NaN      NaN       NaN        NaN       NaN
# 3341 NaN  14889.29      NaN      NaN      NaN  14889.29   14889.29       NaN
#
# [3342 rows x 8 columns]

# %%
#Obtenemos datos limpios del Dataframe
data3_iqr= cuanti2020[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data3_iqr
# Out:
#        TC  IMPORTE     IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT  Columna1
# 0     1.0     0.00     NaN      0.0      0.0   2248.28        NaN       NaN
# 1     1.0   490.00   78.40      0.0      0.0    568.40     568.40       0.0
# 2     1.0   195.00   31.20      0.0      0.0    226.20     226.20       0.0
# 3     1.0      NaN     NaN      0.0      0.0       NaN        NaN       0.0
# 4     1.0     0.00  519.80      0.0      0.0      0.00       0.00       0.0
# ...   ...      ...     ...      ...      ...       ...        ...       ...
# 3337  1.0   129.79   20.21      0.0      0.0    150.00     150.00       0.0
# 3338  1.0  2284.80  365.57      0.0      0.0   2650.37    2650.37       0.0
# 3339  1.0   163.79   26.21      0.0      0.0    190.00     190.00       0.0
# 3340  1.0     0.00    0.00      0.0      0.0      0.00       0.00       0.0
# 3341  1.0      NaN    0.00      0.0      0.0       NaN        NaN       0.0
#
# [3342 rows x 8 columns]

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=cuanti2020.isnull().sum()
valores_nulos
# Out:
# TC           0
# IMPORTE      0
# IVA          0
# RET ISR      0
# RET IVA      0
# TOTAL MX     0
# TOTAL SAT    0
# Columna1     0
# dtype: int64

# %%
#Reemplazamos valores atípicos (nulos) del dataframe con "mean"
#Realizamos una copia del dataframe
data5_iqr=cuanti2020.copy()
data5_iqr=data5_iqr.fillna(round(cuanti2020.mean(),1))
data5_iqr
# Out:
#        TC   IMPORTE      IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT  Columna1
# 0     1.0      0.00  2248.28      0.0      0.0   2248.28   16300.00  14051.72
# 1     1.0    490.00    78.40      0.0      0.0    568.40     568.40      0.00
# 2     1.0    195.00    31.20      0.0      0.0    226.20     226.20      0.00
# 3     1.0  10694.25  1711.08      0.0      0.0  12405.33   12405.33      0.00
# 4     1.0      0.00   519.80      0.0      0.0      0.00       0.00      0.00
# ...   ...       ...      ...      ...      ...       ...        ...       ...
# 3337  1.0    129.79    20.21      0.0      0.0    150.00     150.00      0.00
# 3338  1.0   2284.80   365.57      0.0      0.0   2650.37    2650.37      0.00
# 3339  1.0    163.79    26.21      0.0      0.0    190.00     190.00      0.00
# 3340  1.0      0.00     0.00      0.0      0.0      0.00       0.00      0.00
# 3341  1.0  14889.29     0.00      0.0      0.0  14889.29   14889.29      0.00
#
# [3342 rows x 8 columns]

# %%
#Reemplazamos valores atípicos (nulos) del dataframe con "mean"
#Realizamos una copia del dataframe
data6_iqr=cuali2020.copy()
data6_iqr=data5_iqr.fillna(round(cuali2020.mean()))
data6_iqr
# Out:
# <ipython-input-58-8b60906e1442>:4: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   data6_iqr=data5_iqr.fillna(round(cuali2020.mean()))
# <ipython-input-58-8b60906e1442>:4: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data6_iqr=data5_iqr.fillna(round(cuali2020.mean()))
#           FECHA                   FOLIO                                  UUID  \
# 0    2020-01-01                   39408  BD20F436-72CC-4BE2-AD37-5999D71AA391
# 1    2020-01-01  0001010100750847116902  85AEAC2E-6395-44A0-9CB9-754D06893375
# 2    2020-01-01  0001010100752163714102  BD0DFE85-D776-41CB-9C5C-4FA7923E687A
# ...

# %%
# Unimos laos datas con el dataframe
Datos_limpios2020_iqr = pd.concat([cuanti2020, cuali2020], axis=1)
Datos_limpios2020_iqr
# Out:
#        TC   IMPORTE      IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT  Columna1  \
# 0     1.0      0.00  2248.28      0.0      0.0   2248.28   16300.00  14051.72
# 1     1.0    490.00    78.40      0.0      0.0    568.40     568.40      0.00
# 2     1.0    195.00    31.20      0.0      0.0    226.20     226.20      0.00
# 3     1.0  10694.25  1711.08      0.0      0.0  12405.33   12405.33      0.00
# 4     1.0      0.00   519.80      0.0      0.0      0.00       0.00      0.00
# ...   ...       ...      ...      ...      ...       ...        ...       ...
# 3337  1.0    129.79    20.21      0.0      0.0    150.00     150.00      0.00
# 3338  1.0   2284.80   365.57      0.0      0.0   2650.37    2650.37      0.00
# 3339  1.0    163.79    26.21      0.0      0.0    190.00     190.00      0.00
# 3340  1.0      0.00     0.00      0.0      0.0      0.00       0.00      0.00
# 3341  1.0  14889.29     0.00      0.0      0.0  14889.29   14889.29      0.00
#
# ...

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=Datos_limpios2020_iqr.isnull().sum()
valores_nulos
# Out:
# TC                0
# IMPORTE           0
# IVA               0
# RET ISR           0
# RET IVA           0
# TOTAL MX          0
# TOTAL SAT         0
# Columna1          0
# FECHA             0
# FOLIO           189
# UUID              0
# RFC               0
# PROVEEDOR         0
# TIPO GASTO        0
# DESCRIPCION       0
# TIPO              1
# STATUS            0
# POLIZA         3321
# dtype: int64

# %%
#Convertir DataFrame a CSV
Datos_limpios2020_iqr.to_csv("Datos_limpios2020_iqr.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files 
  
  
files.download("Datos_limpios.csv")
